# %%
import numpy as np
import pandas as pd
data = pd.read_csv('pizza.txt')
print(data)
# Out:
#     X   Y
# 0  13  33
# 1  2   16
# 2  14  32
# 3  23  51
# 4  13  27

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set() # activate Seaborn
plt.axis([0, 50, 0, 50]) # scale axes (0 to 50)
plt.xlabel("Reservations", fontsize=20) # set x axis label
plt.ylabel("Pizzas", fontsize=20) # set y axis label
X, Y = np.loadtxt("pizza.txt", skiprows=1, unpack=True) # load data
plt.plot(X, Y, "bo") # plot data
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set() # activate Seaborn
plt.axis([0, 50, 0, 50]) # scale axes (0 to 50)
plt.xlabel("Reservations", fontsize=20) # set x axis label
plt.ylabel("Pizzas", fontsize=20) # set y axis label
X, Y = np.loadtxt("pizza.txt", skiprows=1, unpack=True) # load data
plt.plot(X, Y, "bo") # plot data
plt.show()

# %%
# Out:
#   File "<ipython-input-5-af8e3f4d32e8>", line 2
#     return X * w
#          ^
# IndentationError: expected an indented block

# %%
# Out:
#   File "<ipython-input-6-27a130e143d7>", line 2
#     return X * w;
#          ^
# IndentationError: expected an indented block

# %%
# Out:
# [19.5  3.  21.  34.5 19.5]
